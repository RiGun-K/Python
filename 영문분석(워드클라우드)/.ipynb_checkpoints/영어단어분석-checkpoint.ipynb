# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\rigun\anaconda3\lib\site-packages (3.4.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rigun\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rigun\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\rigun\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: numpy>=1.16 in c:\users\rigun\anaconda3\lib\site-packages (from matplotlib) (1.20.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\rigun\anaconda3\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\rigun\anaconda3\lib\site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: six in c:\users\rigun\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib) (1.16.0)

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\rigun\anaconda3\lib\site-packages (1.8.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\rigun\anaconda3\lib\site-packages (from wordcloud) (1.20.3)
# Requirement already satisfied: pillow in c:\users\rigun\anaconda3\lib\site-packages (from wordcloud) (8.4.0)
# Requirement already satisfied: matplotlib in c:\users\rigun\anaconda3\lib\site-packages (from wordcloud) (3.4.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rigun\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\rigun\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\rigun\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rigun\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: six in c:\users\rigun\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib->wordcloud) (1.16.0)

# %%
import pandas as pd
import glob
import re
from functools import reduce
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import STOPWORDS, WordCloud
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\RiGun\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\RiGun\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\RiGun\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %%
all_files = glob.glob('C:/Users/RiGun/Python/영문분석(워드클라우드)/myCabinetExcelData*.xls')
all_files  # 출력하여 내용 확인
# Out:
# ['C:/Users/RiGun/Python/영문분석(워드클라우드)\\myCabinetExcelData (1).xls',
#  'C:/Users/RiGun/Python/영문분석(워드클라우드)\\myCabinetExcelData (2).xls',
#  'C:/Users/RiGun/Python/영문분석(워드클라우드)\\myCabinetExcelData (3).xls',
#  'C:/Users/RiGun/Python/영문분석(워드클라우드)\\myCabinetExcelData (4).xls',
#  'C:/Users/RiGun/Python/영문분석(워드클라우드)\\myCabinetExcelData (5).xls',
#  'C:/Users/RiGun/Python/영문분석(워드클라우드)\\myCabinetExcelData (6).xls',
#  'C:/Users/RiGun/Python/영문분석(워드클라우드)\\myCabinetExcelData (7).xls',
#  'C:/Users/RiGun/Python/영문분석(워드클라우드)\\myCabinetExcelData (8).xls',
#  'C:/Users/RiGun/Python/영문분석(워드클라우드)\\myCabinetExcelData (9).xls',
#  'C:/Users/RiGun/Python/영문분석(워드클라우드)\\myCabinetExcelData.xls']

# %%
all_files_data = [] # 저장할 리스트
for file in all_files:
    data_frame = pd.read_excel(file)
    all_files_data.append(data_frame)
all_files_data[0] # 작업 내용 확인
# Out:
#     Unnamed: 0   번호                                                 제목  \
# 0          NaN    1  Health big data analytics: current perspective...
# 1          NaN    2  Analyzing Big Smart Metering Data Towards Diff...
# 2          NaN    3  Improved big data stock index prediction using...
# 3          NaN    4  Guest Editorial: Big Scholar Data Discovery an...
# 4          NaN    5  Guest Editorial: Big Scholar Data Discovery an...
# ..         ...  ...                                                ...
# 95         NaN   96  A Detailed Review on the Prominent Compression...
# 96         NaN   97  Divide and recombine (D&R) data science projec...
# 97         NaN   98  An overview of online based platforms for shar...
# 98         NaN   99  A Survey on Data Collection for Machine Learni...
# 99         NaN  100  The Gamma Matrix to Summarize Dense and Sparse...
#
#                                                    저자  \
# 0   Kuo, Mu-Hsing; Sahama, Tony; Kushniruk, Andre ...
# 1                          Pan, E.; Wang, D.; Han, Z.
# 2         Eapen, Jithin; Verma, Abhishek; Bein, Doina
# 3          Lin, Y.; Tong, H.; Tang, J.; Candan, K. S.
# 4          Lin, Y.; Tong, H.; Tang, J.; Candan, K. S.
# ..                                                ...
# 95                     Anuradha, D.; Bhuvaneswari, S.
# 96  Tung, Wen-wen; Barthur, Ashrith; Bowers, Matth...
# 97  Chen, Yang; Wang, Zhong‐yi; Yuan, Gang; Huang,...
# 98        Roh, Yuji; Heo, Geon; Whang, Steven Euijong
# 99                Ordonez, C.; Zhang, Y.; Cabrera, W.
#
#                                              출판사   출판일
# 0                                   Inderscience  2014
# 1                                        unknown  2016
# 2                                   Inderscience  2021
# 3                                        unknown  2017
# 4                                        unknown  2016
# ..                                           ...   ...
# 95             Springer Science + Business Media  2016
# 96                               Springer Nature  2018
# 97                         John Wiley & Sons Ltd  2017
# 98  IEEE INSTITUTE OF ELECTRICAL AND ELECTRONICS  2021
# 99  IEEE INSTITUTE OF ELECTRICAL AND ELECTRONICS  2016
#
# [100 rows x 6 columns]

# %%
all_files_data_concat = pd.concat(all_files_data, axis = 0, ignore_index = True)
all_files_data_concat # 출력하여 내용 확인
# Out:
#      Unnamed: 0   번호                                                 제목  \
# 0           NaN    1  Health big data analytics: current perspective...
# 1           NaN    2  Analyzing Big Smart Metering Data Towards Diff...
# 2           NaN    3  Improved big data stock index prediction using...
# 3           NaN    4  Guest Editorial: Big Scholar Data Discovery an...
# 4           NaN    5  Guest Editorial: Big Scholar Data Discovery an...
# ..          ...  ...                                                ...
# 995         NaN   96  Improved big data stock index prediction using...
# 996         NaN   97  A big data analytics framework for border cros...
# 997         NaN   98  Health big data analytics: current perspective...
# 998         NaN   99            Intelligent big data analysis: a review
# 999         NaN  100                        Scalable big data modelling
#
#                                                     저자           출판사   출판일
# 0    Kuo, Mu-Hsing; Sahama, Tony; Kushniruk, Andre ...  Inderscience  2014
# 1                           Pan, E.; Wang, D.; Han, Z.       unknown  2016
# 2          Eapen, Jithin; Verma, Abhishek; Bein, Doina  Inderscience  2021
# 3           Lin, Y.; Tong, H.; Tang, J.; Candan, K. S.       unknown  2017
# 4           Lin, Y.; Tong, H.; Tang, J.; Candan, K. S.       unknown  2016
# ..                                                 ...           ...   ...
# 995        Eapen, Jithin; Verma, Abhishek; Bein, Doina  Inderscience  2021
# 996                   Wang, Haibo; Huo, Da; Xu, Yaquan  Inderscience  2017
# 997  Kuo, Mu-Hsing; Sahama, Tony; Kushniruk, Andre ...  Inderscience  2014
# 998  Tsai, Chun-Wei; Yang, Ya-Lan; Chiang, Ming-Cha...  Inderscience  2014
# 999                                      Patel, Jayesh  Inderscience  2021
#
# [1000 rows x 6 columns]

# %%
all_files_data_concat.to_csv('C:/Users/RiGun/Python/영문분석(워드클라우드)/riss_bigdata.csv', encoding='utf-8', index=False)

# %%
all_title = all_files_data_concat['제목']
all_title # 출력하여 내용 확인
# Out:
# 0      Health big data analytics: current perspective...
# 1      Analyzing Big Smart Metering Data Towards Diff...
# 2      Improved big data stock index prediction using...
# 3      Guest Editorial: Big Scholar Data Discovery an...
# 4      Guest Editorial: Big Scholar Data Discovery an...
#                              ...
# 995    Improved big data stock index prediction using...
# 996    A big data analytics framework for border cros...
# 997    Health big data analytics: current perspective...
# 998              Intelligent big data analysis: a review
# 999                          Scalable big data modelling
# Name: 제목, Length: 1000, dtype: object

# %%
stopWords = set(stopwords.words("english"))
lemma = WordNetLemmatizer()

# %%
words = [] 
for title in all_title: 
    EnWords = re.sub(r"[^a-zA-Z]+", " ", str(title)) 
    EnWordsToken = word_tokenize(EnWords.lower()) 
    EnWordsTokenStop = [w for w in EnWordsToken if w not in stopWords] 
    EnWordsTokenStopLemma = [lemma.lemmatize(w) for w in  EnWordsTokenStop]         
    words.append(EnWordsTokenStopLemma)

# %%
print(words) # 출력하여 내용 확인
# Out:
# [['health', 'big', 'data', 'analytics', 'current', 'perspective', 'challenge', 'potential', 'solution'], ['analyzing', 'big', 'smart', 'metering', 'data', 'towards', 'differentiated', 'user', 'service', 'sublinear', 'approach'], ['improved', 'big', 'data', 'stock', 'index', 'prediction', 'using', 'deep', 'learning', 'cnn', 'gru'], ['guest', 'editorial', 'big', 'scholar', 'data', 'discovery', 'collaboration'], ['guest', 'editorial', 'big', 'scholar', 'data', 'discovery', 'collaboration'], ['guest', 'editorial', 'big', 'data', 'analytics', 'web'], ['speed', 'big', 'data', 'analytics', 'unveiling', 'storage', 'distribution', 'sub', 'datasets'], ['guest', 'editorial', 'big', 'data', 'infrastructure'], ['guest', 'editorial', 'big', 'data', 'analytics', 'web'], ['thermal', 'aware', 'dvfs', 'enabled', 'big', 'data', 'task', 'scheduling', 'data', 'center'], ['smart', 'monitoring', 'camera', 'driven', 'intelligent', 'processing', 'big', 'surveillance', 'video', 'data'], ['towards', 'max', 'min', 'fair', 'resource', 'allocation', 'stream', 'big', 'data', 'analytics', 'shared', 'cloud'], ['index', 'ieee', 'transaction', 'big', 'data', 'vol'], ['perception', 'independent', 'financial', 'advisor', 'usefulness', 'big', 'data', 'context', 'decision', 'making', 'uk'], ['online', 'similarity', 'learning', 'big', 'data', 'overfitting'], ['kvasir', 'scalable', 'provision', 'semantically', 'relevant', 'web', 'content', 'big', 'data', 'framework'], ['optimized', 'deep', 'learning', 'eeg', 'big', 'data', 'seizure', 'prediction', 'bci', 'via', 'internet', 'thing'], ['dip', 'svm', 'distribution', 'preserving', 'kernel', 'support', 'vector', 'machine', 'big', 'data'], ['hdm', 'composable', 'framework', 'big', 'data', 'processing'], ['concentric', 'framework', 'leveraging', 'big', 'data', 'business', 'value'], ['structural', 'balance', 'theory', 'based', 'e', 'commerce', 'recommendation', 'big', 'rating', 'data'], ['availability', 'modelling', 'assurance', 'big', 'data', 'computing'], ['survey', 'development', 'context', 'aware', 'monitoring', 'healthcare', 'big', 'data'], ['platform', 'big', 'data', 'analytics', 'distributed', 'scale', 'storage', 'system'], ['platform', 'big', 'data', 'analytics', 'distributed', 'scale', 'storage', 'system'], ['enhanced', 'visualization', 'method', 'aid', 'behavioral', 'trajectory', 'pattern', 'recognition', 'infrastructure', 'big', 'longitudinal', 'data'], ['distributed', 'feature', 'selection', 'efficient', 'economic', 'big', 'data', 'analysis'], ['index', 'ieee', 'transaction', 'big', 'data', 'vol'], ['resting', 'state', 'fmri', 'functional', 'connectivity', 'big', 'data', 'preprocessing', 'pipeline', 'topological', 'data', 'analysis'], ['fuzzy', 'based', 'scalable', 'clustering', 'algorithm', 'handling', 'big', 'data', 'using', 'apache', 'spark'], ['nosql', 'database', 'big', 'data'], ['large', 'scale', 'spectral', 'clustering', 'managing', 'big', 'data', 'healthcare', 'operation'], ['parallel', 'computing', 'preserving', 'privacy', 'using', 'k', 'anonymisation', 'algorithm', 'big', 'data'], ['hybridisation', 'classifier', 'anomaly', 'detection', 'big', 'data'], ['five', 'layer', 'architecture', 'big', 'data', 'processing', 'analytics'], ['fast', 'approach', 'semantic', 'service', 'composition', 'big', 'data', 'environment'], ['toward', 'efficient', 'flexible', 'metadata', 'indexing', 'big', 'data', 'system'], ['towards', 'real', 'time', 'big', 'data', 'analytics', 'platform', 'health', 'application'], ['towards', 'quality', 'service', 'driven', 'consistency', 'big', 'data', 'management'], ['secure', 'multi', 'owner', 'based', 'cloud', 'computing', 'scheme', 'big', 'data'], ['taxi', 'passenger', 'demand', 'modeling', 'based', 'big', 'data', 'roving', 'sensor', 'network'], ['current', 'trend', 'predictive', 'analytics', 'big', 'data'], ['towards', 'quality', 'service', 'driven', 'consistency', 'big', 'data', 'management'], ['classification', 'comparison', 'nosql', 'big', 'data', 'model'], ['survey', 'big', 'data',  ...

# %%
words2 = list(reduce(lambda x, y: x+y, words))
print(words2) #출력하여 내용 확인
# Out:
# ['health', 'big', 'data', 'analytics', 'current', 'perspective', 'challenge', 'potential', 'solution', 'analyzing', 'big', 'smart', 'metering', 'data', 'towards', 'differentiated', 'user', 'service', 'sublinear', 'approach', 'improved', 'big', 'data', 'stock', 'index', 'prediction', 'using', 'deep', 'learning', 'cnn', 'gru', 'guest', 'editorial', 'big', 'scholar', 'data', 'discovery', 'collaboration', 'guest', 'editorial', 'big', 'scholar', 'data', 'discovery', 'collaboration', 'guest', 'editorial', 'big', 'data', 'analytics', 'web', 'speed', 'big', 'data', 'analytics', 'unveiling', 'storage', 'distribution', 'sub', 'datasets', 'guest', 'editorial', 'big', 'data', 'infrastructure', 'guest', 'editorial', 'big', 'data', 'analytics', 'web', 'thermal', 'aware', 'dvfs', 'enabled', 'big', 'data', 'task', 'scheduling', 'data', 'center', 'smart', 'monitoring', 'camera', 'driven', 'intelligent', 'processing', 'big', 'surveillance', 'video', 'data', 'towards', 'max', 'min', 'fair', 'resource', 'allocation', 'stream', 'big', 'data', 'analytics', 'shared', 'cloud', 'index', 'ieee', 'transaction', 'big', 'data', 'vol', 'perception', 'independent', 'financial', 'advisor', 'usefulness', 'big', 'data', 'context', 'decision', 'making', 'uk', 'online', 'similarity', 'learning', 'big', 'data', 'overfitting', 'kvasir', 'scalable', 'provision', 'semantically', 'relevant', 'web', 'content', 'big', 'data', 'framework', 'optimized', 'deep', 'learning', 'eeg', 'big', 'data', 'seizure', 'prediction', 'bci', 'via', 'internet', 'thing', 'dip', 'svm', 'distribution', 'preserving', 'kernel', 'support', 'vector', 'machine', 'big', 'data', 'hdm', 'composable', 'framework', 'big', 'data', 'processing', 'concentric', 'framework', 'leveraging', 'big', 'data', 'business', 'value', 'structural', 'balance', 'theory', 'based', 'e', 'commerce', 'recommendation', 'big', 'rating', 'data', 'availability', 'modelling', 'assurance', 'big', 'data', 'computing', 'survey', 'development', 'context', 'aware', 'monitoring', 'healthcare', 'big', 'data', 'platform', 'big', 'data', 'analytics', 'distributed', 'scale', 'storage', 'system', 'platform', 'big', 'data', 'analytics', 'distributed', 'scale', 'storage', 'system', 'enhanced', 'visualization', 'method', 'aid', 'behavioral', 'trajectory', 'pattern', 'recognition', 'infrastructure', 'big', 'longitudinal', 'data', 'distributed', 'feature', 'selection', 'efficient', 'economic', 'big', 'data', 'analysis', 'index', 'ieee', 'transaction', 'big', 'data', 'vol', 'resting', 'state', 'fmri', 'functional', 'connectivity', 'big', 'data', 'preprocessing', 'pipeline', 'topological', 'data', 'analysis', 'fuzzy', 'based', 'scalable', 'clustering', 'algorithm', 'handling', 'big', 'data', 'using', 'apache', 'spark', 'nosql', 'database', 'big', 'data', 'large', 'scale', 'spectral', 'clustering', 'managing', 'big', 'data', 'healthcare', 'operation', 'parallel', 'computing', 'preserving', 'privacy', 'using', 'k', 'anonymisation', 'algorithm', 'big', 'data', 'hybridisation', 'classifier', 'anomaly', 'detection', 'big', 'data', 'five', 'layer', 'architecture', 'big', 'data', 'processing', 'analytics', 'fast', 'approach', 'semantic', 'service', 'composition', 'big', 'data', 'environment', 'toward', 'efficient', 'flexible', 'metadata', 'indexing', 'big', 'data', 'system', 'towards', 'real', 'time', 'big', 'data', 'analytics', 'platform', 'health', 'application', 'towards', 'quality', 'service', 'driven', 'consistency', 'big', 'data', 'management', 'secure', 'multi', 'owner', 'based', 'cloud', 'computing', 'scheme', 'big', 'data', 'taxi', 'passenger', 'demand', 'modeling', 'based', 'big', 'data', 'roving', 'sensor', 'network', 'current', 'trend', 'predictive', 'analytics', 'big', 'data', 'towards', 'quality', 'service', 'driven', 'consistency', 'big', 'data', 'management', 'classification', 'comparison', 'nosql', 'big', 'data', 'model', 'survey', 'big', 'data', 'processing', 'infrastructure', 'evolving', 'role', 'fpga', 'hierarchical', 'distributed' ...

# %%
count = Counter(words2)
count #출력하여 내용 확인
# Out:
# Counter({'health': 31,
#          'big': 1125,
#          'data': 1252,
#          'analytics': 93,
#          'current': 11,
#          'perspective': 26,
#          'challenge': 56,
#          'potential': 14,
#          'solution': 15,
#          'analyzing': 6,
#          'smart': 26,
#          'metering': 4,
#          'towards': 14,
#          'differentiated': 3,
#          'user': 4,
#          'service': 22,
#          'sublinear': 3,
#          'approach': 53,
#          'improved': 7,
#          'stock': 6,
#          'index': 8,
#          'prediction': 21,
#          'using': 60,
#          'deep': 12,
#          'learning': 43,
#          'cnn': 3,
#          'gru': 3,
#          'guest': 15,
#          'editorial': 17,
#          'scholar': 3,
#          'discovery': 11,
#          'collaboration': 5,
#          'web': 8,
#          'speed': 1,
#          'unveiling': 1,
#          'storage': 8,
#          'distribution': 9,
#          'sub': 1,
#          'datasets': 2,
#          'infrastructure': 10,
#          'thermal': 2,
#          'aware': 4,
#          'dvfs': 1,
#          'enabled': 9,
#          'task': 3,
#          'scheduling': 5,
#          'center': 10,
#          'monitoring': 9,
#          'camera': 1,
#          'driven': 56,
#          'intelligent': 14,
#          'processing': 24,
#          'surveillance': 2,
#          'video': 2,
#          'max': 1,
#          'min': 1,
#          'fair': 1,
#          'resource': 2,
#          'allocation': 2,
#          'stream': 4,
#          'shared': 2,
#          'cloud': 24,
#          'ieee': 2,
#          'transaction': 2,
#          'vol': 2,
#          'perception': 3,
#          'independent': 3,
#          'financial': 10,
#          'advisor': 1,
#          'usefulness': 1,
#          'context': 9,
#          'decision': 14,
#          'making': 16,
#          'uk': 1,
#          'online': 13,
#          'similarity': 4,
#          'overfitting': 1,
#          'kvasir': 1,
#          'scalable': 16,
#          'provision': 2,
#          'semantically': 2,
#          'relevant': 2,
#          'content': 6,
#          'framework': 34,
#          'optimized': 3,
#          'eeg': 1,
#          'seizure': 1,
#          'bci': 1,
#          'via': 6,
#          'internet': 13,
#          'thing': 10,
#          'dip': 1,
#          'svm': 2,
#          'preserving': 3,
#          'kernel': 3,
#          'support': 13,
#          'vector': 3,
#          'machine': 25,
#          'hdm': 1,
#          'composable': 1,
#          'concentric': 1,
#          'leveraging': 6,
#          'business': 22,
#          'value': 13,
#          'structural': 3,
#          'balance': 2,
#          'theory': 5,
#          'based': 89,
#          'e': 8,
#          'commerce': 1,
#          'recommendation': 6,
#          'rating': 3,
#          'availability': 2,
#          'modelling': 6,
#          'assurance': 1,
#          'computing': 20,
#          'survey': 22,
#          'development': 18,
#          'healthcare': 13,
#          'platform': 29,
#          'distributed': 20,
#          'scale': 11,
#          'system': 46,
#          'enhanced': 3,
#          'visualization': 7,
#          'method': 19,
#          'aid': 1,
#          'behavioral': 5,
#          'trajectory': 2,
#          'pattern': 8,
#          'recognition': 1,
#          'longitudinal': 2,
#          'feature': 5,
#          'selection': 5,
#          'efficient': 18,
#          'economic': 2,
#          'analysis': 75,
#          'resting': 1,
#          'state': 11,
#          'fmri': 1,
#          'functional': 1,
#          'connectivity': 1,
#          'preprocessing': 1,
#          'pipeline': 3,
#          'topological': 1,
#          'fuzzy': 4,
#          'clustering': 7,
#          'algorithm': 21,
#          'handling': 5,
#          'apache': 6,
#          'spark': 5,
#          'nosql': 3,
#          'database': 8,
#          'large': 13,
#          'spectral': 1,
#          'managing': 5,
#          'operation': 4,
#          'parallel': 5,
#          'privacy': 12,
#          'k': 10,
#          'anonymisation': 1,
#          'hybridisation': 1,
#          'classifier': 2,
#          'anomaly': 3,
#          'detection': 10,
#          'five': 3,
#          'layer': 1,
#          'architecture': 9,
#          'fast': 2,
#          'semantic': 7,
#          'composition': 2,
#          'environment': 9,
#          'toward': 11,
#          'flexible': 2,
#          'metadata': 2,
#          'indexing': 1,
#          'real': 17,
#          'time': 18,
#          'application': 30,
#          'quality': 10,
#          'consistency': 2,
#          'management': 34,
#          'secure': 1,
#          'multi': 11,
#          'owner': 1,
#          'scheme': 4,
#          'taxi': 2,
#          'passenger': 1,
#          'demand': 3,
#          'modeling': 11,
#          'roving': 1,
#          'sensor': 7,
#          'network': 22,
#          'trend': 9,
#          'predictive': 9,
#          'classification': 8,
#          'comparison': 3,
#          'model': 40,
#          'evolving': 2,
#          'role': 9,
#          'fpga': 1,
#          'hierarchical': 1,
#          'image': 6,
#          'reference': 2,
#          'introducing': 1,
#          'perform': 1,
#          'technology': 21,
#          'extended': 3,
#          'spatio': 3,
#          'temporal': 4,
#          'granger': 1,
#          'causality': 1,
#          'air': 3,
#          'estimation': 5,
#          'heterogeneous': 6,
#          'urban': 8,
#          'corporate': 3,
#          'governance': 5,
#          'fraud': 2,
#          'annual': 1,
#          'report': 4,
#          'palopro': 1,
#          'knowledge': 14,
#          'extraction': 3,
#          'social': 22,
#          'news': 4,
#          'review': 24,
#          'ethical': 2,
#          'concern': 1,
#          'deduplication': 2,
#          'encrypted': 1,
#          'petuum': 1,
#          'new': 48,
#          'algorithmseer': 1,
#          'extracting': 2,
#          'searching': 1,
#          'scholarly': 4,
#          'special': 24,
#          'issue': 36,
#          'continued': 2,
#          'view': 4,
#          'cube': 1,
#          'earth': 26,
#          'interoperability': 2,
#          'comprehensive': 3,
#          'frontier': 6,
#          'information': 22,
#          'science': 37,
#          'gsio': 1,
#          'programmatic': 1,
#          'interface': 1,
#          'delivering': 1,
#          'facilitates': 1,
#          'sustainable': 15,
#          'goal': 11,
#          'stewardship': 1,
#          'observation': 8,
#          'innovative': 2,
#          'generalized': 3,
#          'supervised': 2,
#          'produce': 1,
#          'provincial': 1,
#          'wetland': 1,
#          'inventory': 1,
#          'map': 4,
#          'google': 4,
#          'engine': 3,
#          'geo': 3,
#          'exploiting': 2,
#          'space': 5,
#          'first': 3,
#          'experience': 3,
#          'timescan': 1,
#          'chain': 6,
#          'geospatial': 5,
#          'semantics': 4,
#          'ontology': 3,
#          'graph': 4,
#          'understanding': 15,
#          'climate': 3,
#          'change': 5,
#          'way': 7,
#          'open': 10,
#          'geosocial': 1,
#          'medium': 14,
#          'crowdsourced': 1,
#          'visual': 7,
#          'public': 9,
#          'transport': 2,
#          'performance': 17,
#          'greater': 1,
#          'sydney': 1,
#          'sentinel': 3,
#          'landsat': 2,
#          'imagery': 1,
#          'global': 10,
#          'human': 13,
#          'settlement': 1,
#          'mapping': 5,
#          'utilization': 4,
#          'core': 2,
#          'processor': 4,
#          'many': 1,
#          'co': 3,
#          'supercomputer': 1,
#          'beacon': 1,
#          'geocomputation': 1,
#          'simulation': 3,
#          'spatial': 9,
#          'sentiment': 5,
#          'educational': 1,
#          'simd': 1,
#          'mcmc': 1,
#          'sampling': 3,
#          'bayesian': 4,
#          'mining': 23,
#          'small': 18,
#          'enterprise': 7,
#          'transportation': 8,
#          'sector': 5,
#          'improving': 1,
#          'shuffle': 1,
#          'phase': 6,
#          'hadoop': 3,
#          'reduce': 1,
#          'bigger': 4,
#          'biggest': 3,
#          'repository': 2,
#          'balloon': 1,
#          'unprecedented': 1,
#          'level': 2,
#          'coping': 3,
#          'transforming': 5,
#          'insight': 7,
#          'use': 21,
#          'nearest': 3,
#          'neighbor': 2,
#          'obtain': 1,
#          'meet': 5,
#          'formal': 1,
#          'practical': 4,
#          'novel': 6,
#          'paradigm': 4,
#          'forecasting': 6,
#          'organisation': 2,
#          'leverage': 3,
#          'maturity': 1,
#          'quantile': 1,
#          'regression': 3,
#          'divide': 2,
#          'conquer': 1,
#          'strategy': 7,
#          'statistical': 6,
#          'double': 1,
#          'log': 2,
#          'skew': 1,
#          'symmetric': 1,
#          'error': 5,
#          'always': 1,
#          'yield': 2,
#          'benefit': 5,
#          'discretization': 1,
#          'taxonomy': 1,
#          'result': 1,
#          'output': 1,
#          'process': 16,
#          'attribute': 1,
#          'designing': 2,
#          'operating': 1,
#          'mine': 2,
#          'engineering': 8,
#          'geographical': 1,
#          'condition': 3,
#          'automated': 1,
#          'slicing': 1,
#          'validation': 1,
#          'ai': 5,
#          'integration': 4,
#          'build': 2,
#          'better': 3,
#          'em': 2,
#          'detailed': 1,
#          'prominent': 1,
#          'compression': 5,
#          'used': 5,
#          'reducing': 2,
#          'volume': 2,
#          'recombine': 1,
#          'r': 10,
#          'project': 7,
#          'high': 13,
#          'computational': 10,
#          'complexity': 2,
#          'overview': 4,
#          'sharing': 6,
#          'electrophysiology': 1,
#          'collection': 2,
#          'gamma': 1,
#          'matrix': 2,
#          'summarize': 1,
#          'dense': 1,
#          'sparse': 4,
#          'set': 4,
#          'haery': 1,
#          'query': 4,
#          'accumulative': 1,
#          'dimensional': 3,
#          'security': 13,
#          'criminal': 1,
#          'investigation': 2,
#          'international': 5,
#          'conference': 1,
#          'bigcomp': 1,
#          'mapreduce': 7,
#          'programming': 1,
#          'applying': 5,
#          'kansei': 1,
#          'hotel': 1,
#          'academic': 3,
#          'librarian': 4,
#          'competency': 1,
#          'skill': 2,
#          'implementation': 6,
#          'library': 1,
#          'fusion': 3,
#          'done': 2,
#          'status': 7,
#          'assessment': 5,
#          'peer': 1,
#          'produced': 1,
#          'case': 13,
#          'implicit': 2,
#          'wikipedia': 1,
#          'cyber': 1,
#          'physical': 1,
#          'chicken': 1,
#          'swarm': 3,
#          'foraging': 1,
#          'belief': 2,
#          'improves': 1,
#          'care': 11,
#          'single': 1,
#          'cell': 3,
#          'transcriptomics': 1,
#          'grand': 2,
#          'opportunity': 31,
#          'intelligence': 15,
#          'revised': 1,
#          'pyramid': 1,
#          'entity': 1,
#          'communication': 3,
#          'tool': 6,
#          'experimental': 3,
#          'evaluation': 4,
#          'tensor': 5,
#          'dimensionality': 1,
#          'reduction': 3,
#          'problem': 8,
#          'grid': 5,
#          'sdn': 1,
#          'exploring': 7,
#          'fundamental': 1,
#          'scientific': 12,
#          'michael': 1,
#          'buck': 2,
#          'talk': 1,
#          'living': 1,
#          'dream': 1,
#          'bioinformaticist': 1,
#          'emerging': 3,
#          'alternative': 2,
#          'warehouse': 4,
#          'coal': 1,
#          'fired': 1,
#          'power': 8,
#          'plant': 1,
#          'partner': 1,
#          'allina': 1,
#          'team': 4,
#          'catalyst': 3,
#          'garner': 1,
#          'memory': 3,
#          'city': 10,
#          'advanced': 5,
#          'rule': 5,
#          'granularity': 1,
#          'phone': 1,
#          'compute': 2,
#          'mobility': 3,
#          'scenario': 3,
#          'future': 17,
#          'heavy': 1,
#          'tailed': 1,
#          'china': 15,
#          'deal': 6,
#          'mongodb': 1,
#          'modular': 1,
#          'building': 7,
#          'predicting': 2,
#          'amazon': 1,
#          'product': 5,
#          'comparing': 1,
#          'world': 18,
#          'regional': 3,
#          'supply': 5,
#          'finance': 2,
#          'bibliometric': 1,
#          'mr': 1,
#          'plot': 1,
#          'distinguishing': 1,
#          'consensus': 1,
#          'lime': 1,
#          'skyline': 1,
#          'computation': 4,
#          'stakeholder': 3,
#          'word': 1,
#          'mouth': 1,
#          'csr': 1,
#          'dynamic': 3,
#          'twitter': 3,
#          'watchdog': 1,
#          'name': 1,
#          'matching': 1,
#          'risk': 9,
#          'evaluating': 4,
#          'design': 8,
#          'methodology': 4,
#          'measurement': 11,
#          'effect': 2,
#          'barrier': 2,
#          'embedding': 1,
#          'factory': 4,
#          'sap': 1,
#          'consultant': 1,
#          'subdata': 1,
#          'unlocking': 1,
#          'causal': 1,
#          'relation': 1,
#          'manufacturing': 9,
#          'firm': 4,
#          'analysing': 3,
#          'repeat': 1,
#          'blood': 1,
#          'donation': 1,
#          'behavior': 7,
#          'incremental': 3,
#          'advancing': 1,
#          'retail': 1,
#          'apriori': 1,
#          'hyper': 1,
#          'convergent': 1,
#          'innovation': 7,
#          'updating': 1,
#          'correct': 1,
#          'holistic': 2,
#          'step': 1,
#          'nonlinear': 1,
#          'dimension': 4,
#          'va': 1,
#          'store': 3,
#          'virtual': 2,
#          'approximate': 1,
#          'supporting': 2,
#          'repetitive': 1,
#          'genome': 2,
#          'sequence': 2,
#          'neighbour': 1,
#          'join': 2,
#          'theoretical': 5,
#          'feasibility': 1,
#          'implication': 5,
#          'era': 28,
#          'pcce': 1,
#          'personality': 1,
#          'communicative': 1,
#          'community': 5,
#          'suspicious': 1,
#          'tax': 1,
#          'evasion': 1,
#          'group': 2,
#          'contextual': 2,
#          'federated': 1,
#          'recommender': 1,
#          'bit': 1,
#          'oriented': 3,
#          'aggregation': 3,
#          'broadcasting': 1,
#          'bias': 2,
#          'correction': 5,
#          'sample': 2,
#          'v': 4,
#          'non': 3,
#          'simple': 3,
#          'pre': 1,
#          'uncertainty': 7,
#          'measure': 2,
#          'conflict': 1,
#          'evidence': 8,
#          'dempster': 1,
#          'shafer': 1,
#          'semi': 1,
#          'automatic': 1,
#          'fact': 1,
#          'market': 12,
#          'direction': 2,
#          'linked': 1,
#          'sequential': 1,
#          'localization': 1,
#          'telco': 1,
#          'effective': 2,
#          'clinical': 12,
#          'source': 1,
#          'recursive': 1,
#          'approximation': 4,
#          'recovery': 3,
#          'sensing': 8,
#          'chunk': 1,
#          'dataset': 1,
#          'sensory': 1,
#          'wireless': 6,
#          'canonical': 1,
#          'correlation': 4,
#          'multiview': 1,
#          'skia': 1,
#          'textual': 1,
#          'factorization': 1,
#          'series': 6,
#          'blind': 1,
#          'factor': 3,
#          'vecchia': 1,
#          'laplace': 1,
#          'gaussian': 2,
#          'emulated': 1,
#          'order': 4,
#          'identification': 5,
#          'distrubted': 1,
#          'dws': 1,
#          'technique': 9,
#          'access': 6,
#          'competitive': 7,
#          'advantage': 4,
#          'car': 3,
#          'hailing': 1,
#          'eu': 1,
#          'law': 4,
#          'face': 2,
#          'shake': 1,
#          'archeological': 1,
#          'site': 2,
#          'b': 2,
#          'year': 1,
#          'old': 2,
#          'chisos': 1,
#          'basin': 1,
#          'bend': 1,
#          'national': 6,
#          'park': 1,
#          'course': 3,
#          'given': 1,
#          'student': 5,
#          'expectation': 1,
#          'industry': 15,
#          'frame': 1,
#          'make': 5,
#          'friendly': 1,
#          'im': 4,
#          'labor': 7,
#          'der': 10,
#          'zukunft': 3,
#          'anwendungen': 1,
#          'chancen': 3,
#          'herausforderungen': 2,
#          'transformation': 7,
#          'enriched': 1,
#          'simplified': 2,
#          'working': 2,
#          'field': 5,
#          'augmented': 1,
#          'ethnography': 1,
#          'study': 21,
#          'candidate': 3,
#          'interaction': 1,
#          'election': 2,
#          'oracle': 2,
#          'sparc': 2,
#          'accelerates': 1,
#          'recent': 5,
#          'integrate': 1,
#          'hardware': 2,
#          'acceleration': 1,
#          'software': 5,
#          'also': 2,
#          'enable': 3,
#          'ready': 2,
#          'research': 32,
#          'hazy': 1,
#          'easier': 1,
#          'maintain': 1,
#          'racing': 1,
#          'unleash': 1,
#          'full': 1,
#          'latest': 1,
#          'losungen': 2,
#          'fur': 3,
#          'netzbetreiber': 2,
#          'siemens': 2,
#          'und': 9,
#          'teradata': 2,
#          'vereinbaren': 2,
#          'globale': 2,
#          'zusammenarbeit': 2,
#          'technical': 2,
#          'critical': 9,
#          'literature': 4,
#          'multiperspective': 2,
#          'edge': 4,
#          'biomarkers': 2,
#          'dynamical': 2,
#          'drug': 7,
#          'sensitivity': 3,
#          'resistance': 3,
#          'individual': 4,
#          'formation': 2,
#          'entropy': 3,
#          'alloy': 2,
#          'architecting': 2,
#          'migration': 2,
#          'execute': 2,
#          'bioinformatics': 2,
#          'workflow': 3,
#          'consequence': 3,
#          'education': 7,
#          'multiple': 5,
#          'target': 4,
#          'tracking': 3,
#          'binary': 2,
#          'shift': 3,
#          'keying': 2,
#          'transceiver': 2,
#          'capturing': 3,
#          'biosurveillance': 2,
#          'natural': 3,
#          'capital': 3,
#          'accounting': 6,
#          'bring': 2,
#          'beyond': 4,
#          'hype': 3,
#          'boe': 2,
#          'fusing': 2,
#          'spanish': 2,
#          'official': 2,
#          'gazette': 2,
#          'diversity': 4,
#          'water': 5,
#          'cycle': 2,
#          'remote': 3,
#          'propaganda': 6,
#          'political': 10,
#          'moving': 8,
#          'agenda': 2,
#          'really': 3,
#          'junqu': 2,
#          'de': 7,
#          'fortuny': 2,
#          'marten': 2,
#          'provost': 2,
#          'f': 7,
#          'relationship': 9,
#          'training': 5,
#          'pedagogy': 2,
#          'graduate': 2,
#          'teamwork': 2,
#          'box': 2,
#          'office': 2,
#          'call': 20,
#          'paper': 21,
#          'futuristic': 2,
#          'fabric': 2,
#          'societal': 2,
#          'digital': 9,
#          'author': 4,
#          'response': 5,
#          'gong': 2,
#          'comment': 4,
#          'essential': 2,
#          'land': 2,
#          'category': 2,
#          'euluc': 2,
#          'progress': 3,
#          'idea': 3,
#          'geological': 2,
#          'sport': 7,
#          'next': 11,
#          'pythia': 2,
#          'missing': 2,
#          'rf': 2,
#          'localisation': 2,
#          'unmanned': 2,
#          'search': 11,
#          'rescue': 2,
#          'part': 3,
#          'accurate': 4,
#          'cluster': 5,
#          'mean': 7,
#          'biomedical': 2,
#          'soom': 2,
#          'sort': 2,
#          'optimizer': 2,
#          'interview': 2,
#          'dr': 2,
#          'silvio': 2,
#          'carta': 2,
#          'book': 2,
#          'code': 2,
#          'discrete': 2,
#          'routledge': 2,
#          'u': 9,
#          'army': 2,
#          'person': 2,
#          'event': 2,
#          'military': 2,
#          'civilian': 2,
#          'swimming': 2,
#          'pool': 2,
#          'impact': 14,
#          'household': 2,
#          'electric': 6,
#          'intensity': 9,
#          'san': 2,
#          'antonio': 2,
#          'texas': 2,
#          'unsupervised': 2,
#          'practitioner': 3,
#          'ensemble': 5,
#          'intrusion': 2,
#          'robotics': 6,
#          'understand': 3,
#          'kavli': 2,
#          'guide': 4,
#          'guided': 2,
#          'end': 3,
#          'daily': 2,
#          'fantasy': 2,
#          'know': 4,
#          'tv': 2,
#          'audience': 2,
#          'good': 7,
#          'discrimination': 3,
#          'diagram': 2,
#          'basalt': 2,
#          'medical': 10,
#          'school': 4,
#          'relate': 2,
#          'practice': 10,
#          'us': 2,
#          'scalability': 2,
#          'batch': 3,
#          'flink': 2,
#          'population': 6,
#          'mobile': 10,
#          'monitor': 2,
#          'common': 2,
#          'overcome': 2,
#          'enabler': 2,
#          'primary': 3,
#          'administration': 2,
#          'dilemma': 2,
#          'exercise': 2,
#          'producing': 2,
#          'reliable': 2,
#          'combining': 2,
#          'sense': 2,
#          'aerial': 3,
#          'disaster': 5,
#          'analyze': 3,
#          'little': 11,
#          'coordination': 2,
#          'medicare': 2,
#          'beneficiary': 2,
#          'medigap': 2,
#          'coverage': 2,
#          'cataclysm': 2,
#          'optimizing': 4,
#          'uncertain': 2,
#          'hypothesis': 2,
#          'theoretic': 2,
#          'rise': 3,
#          'cybersecurity': 3,
#          'advance': 5,
#          'hydrology': 3,
#          'protecting': 2,
#          'virtualized': 2,
#          'comparative': 3,
#          'adakites': 2,
#          'mineralization': 2,
#          'related': 4,
#          'granite': 2,
#          'geza': 2,
#          'arc': 3,
#          'metallogenic': 2,
#          'belt': 2,
#          'northwest': 2,
#          'yunnan': 2,
#          'southwest': 2,
#          'stgi': 2,
#          'marine': 3,
#          'routing': 3,
#          'gathering': 4,
#          'landslide': 2,
#          'curating': 2,
#          'made': 5,
#          'drive': 3,
#          'lost': 4,
#          'celebration': 2,
#          'establishment': 3,
#          'cbas': 2,
#          'economist': 3,
#          'get': 3,
#          'microscope': 2,
#          'behaviour': 2,
#          'strength': 2,
#          'number': 3,
#          'simplify': 2,
#          'engagement': 2,
#          'hungary': 2,
#          'sdgs': 2,
#          'atmospheric': 2,
#          'ecosystem': 3,
#          'providing': 2,
#          'key': 6,
#          'contribution': 3,
#          'reaching': 2,
#          'united': 7,
#          'nation': 2,
#          'message': 3,
#          'editor': 4,
#          'chief': 2,
#          'green': 5,
#          'actual': 2,
#          'geoecological': 2,
#          'border': 2,
#          'crossing': 2,
#          'highlight': 1,
#          'parking': 1,
#          'policy': 7,
#          'adherence': 1,
#          'meter': 1,
#          'limit': 1,
#          'washington': 1,
#          'c': 2,
#          'question': 9,
#          'horizontal': 1,
#          'vertical': 1,
#          'discussion': 3,
#          'quantification': 1,
#          'variation': 1,
#          'stem': 1,
#          'tissue': 1,
#          'vision': 3,
#          'unique': 1,
#          'battery': 1,
#          'recycling': 1,
#          'energy': 19,
#          'vehicle': 5,
#          'optimization': 14,
#          'carbon': 2,
#          'emission': 1,
#          'walkable': 1,
#          'satellite': 2,
#          'yearly': 1,
#          'generation': 7,
#          'aiaa': 1,
#          'revamp': 1,
#          'toxicology': 1,
#          'curation': 1,
#          'coming': 1,
#          'promise': 7,
#          'mitigation': 1,
#          'iot': 11,
#          'incorporating': 1,
#          'smallholder': 1,
#          'palm': 1,
#          'oil': 5,
#          'production': 2,
#          'realm': 1,
#          'possibility': 2,
#          'emergence': 2,
#          'textile': 1,
#          'an': 1,
#          'tze': 1,
#          'psychiatrie': 1,
#          'beispiele': 1,
#          'au': 3,
#          'depressionsforschung': 1,
#          'informatics': 3,
#          'smarter': 1,
#          'prevention': 3,
#          'sphps': 1,
#          'interval': 2,
#          'type': 2,
#          ...})

# %%
word_count = dict()
for tag, counts in count.most_common(50):
   if(len(str(tag))>1):
        word_count[tag] = counts
        print("%s : %d" % (tag, counts))
# Out:
# data : 1252
# big : 1125
# analytics : 93
# based : 89
# analysis : 75
# using : 60
# challenge : 56
# driven : 56
# approach : 53
# new : 48
# system : 46
# learning : 43
# model : 40
# science : 37
# issue : 36
# framework : 34
# management : 34
# research : 32
# health : 31
# opportunity : 31
# application : 30
# platform : 29
# era : 28
# perspective : 26
# smart : 26
# earth : 26
# machine : 25
# processing : 24
# cloud : 24
# review : 24
# special : 24
# mining : 23
# service : 22
# business : 22
# survey : 22
# network : 22
# social : 22
# information : 22
# prediction : 21
# algorithm : 21
# technology : 21
# use : 21
# study : 21
# paper : 21
# computing : 20
# distributed : 20
# call : 20
# method : 19
# energy : 19
# development : 18

# %%
sorted_Keys = sorted(word_count, key = word_count.get, reverse = True)
sorted_Values = sorted(word_count.values(), reverse = True)
plt.bar(range(len(word_count)), sorted_Values, align = 'center')
plt.xticks(range(len(word_count)), list(sorted_Keys), rotation = '85')
plt.show()

# %%
del word_count['big']
del word_count['data']
plt.show()

# %%
all_files_data_concat['doc_count'] = 0 
summary_year = all_files_data_concat.groupby('출판일', as_index = False)['doc_count'].count() 
summary_year #출력하여 내용 확인
# Out:
#      출판일  doc_count
# 0   1995          1
# 1   1999          1
# 2   2003          1
# 3   2004          1
# 4   2008          1
# 5   2009          1
# 6   2011          7
# 7   2012         17
# 8   2013         48
# 9   2014        143
# 10  2015        113
# 11  2016        137
# 12  2017        163
# 13  2018        118
# 14  2019        105
# 15  2020         78
# 16  2021         65

# %%
plt.figure(figsize = (12, 5))
plt.xlabel("year")
plt.ylabel("doc-count")
plt.grid(True)
plt.plot(range(len(summary_year)), summary_year['doc_count'])
plt.xticks(range(len(summary_year)), [text for text in summary_year['출판일']])
plt.show()

# %%
stopwords = set(STOPWORDS)
wc = WordCloud(background_color = 'ivory', stopwords = stopwords, width = 800, height = 600)
cloud = wc.generate_from_frequencies(word_count)
plt.figure(figsize = (8,8))
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %%
cloud.to_file("C:/Users/RiGun/Python/영문분석(워드클라우드)/riss_bigdata_wordCloud.jpg")
